# %% [markdown]
# <a href="https://colab.research.google.com/github/kavit-bokarvadiya/python-programming/blob/main/printFunction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **print function**

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello", 1, 2, 4.5, True)
# Out:
# hello 1 2 4.5 True

# %%
print("hello", 1, 2, 4.5, True, sep='/')
# Out:
# hello/1/2/4.5/True

# %% [markdown]
# print(*args, sep=' ', end='\n', file=None, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
#
# end
#   string appended after the last value, default a newline.
#
# file
#   a file-like object (stream); defaults to the current sys.stdout.
#
# flush
#   whether to forcibly flush the stream.

# %%
print("hello", 1, 2, 4.5, True, sep='|')
# Out:
# hello|1|2|4.5|True

# %% [markdown]
# seperator functionality in print function::
#
# print(*args, sep=' ')

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %% [markdown]
# if i can write print function like:
#
# print("hello")
# print("world")
#
# then o/p:
# hello
# world
#
# so, how to solve this problem
# which problem :: line change
#
# see this property avalible in print function
# print(end='\n')
#
# new program is related this problem.

# %%
print("hello", end = ' ')
print("world")
# Out:
# hello world

# %% [markdown]
# **2. Data Types**
